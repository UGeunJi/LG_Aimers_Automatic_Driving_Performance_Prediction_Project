# %% [markdown]
# - 우근
#
# 로그 변환
# x데이터를 변환 : 변수 4개 안됨
# 로그 변환시 큰 차이가 있는 변수들끼리
# 데이터셋 만들어봄
#
# -> 로그 변환은 큰 효과가 없음으로 결론
#
#
# - 주연
#
# X50 ~ 56 // 이상치 평균치로 처리 후 XGBoost모델링
#
# -> cat으로 다시 모델링하여 성능 확인해볼 것
#
#
#
# - 현지
#
# 구간화하는 방법 궁금
#
# -> 다른 방법으로 해볼 예정
#
#
#
# - 종원
#
# 타겟을 하나씩 지정하여 각각 돌려봤지만
# 멀티 아웃풋 리그레서 이용하는것이 더 성능 좋음
# 딥러닝도 마찬가지
# 각 칼럼별로 0.001정도의 차이
#
# -> 딥러닝으로는 어렵겠다고 판단
#
# 정상 비정상 분류
# 정확도 95 % ~ 99%로 분류하지만
# 혼동행렬 시각화해본 결과 의미없음 결론
#
# 정상/비정상, 최소/최대 분류
# -> 테스트 데이터에서 비정상으로 150개 라벨링 가능 예상
# 오늘대로 다시 실험해볼 계획
#
#
#
# - 상민
#
# 데이터를 증강해볼 계획
# 기존 데이터와 섞어본 다음 모델링
#
# one class svm 분류기
# 데이터 불균형이 있어도 9:1로 분류 잘 함
#
#
#
# * max depts를 7에서 줄이니 분류성능이 좋아짐
# * deep svm 할것 없는 분들 추천
# * 정제하지 않은 데이터로 cat 모델링했을때 성능이 가장 좋음
# * 클리핑, 커리큘럼 방식 사용했을때 조금의 성능 향상
